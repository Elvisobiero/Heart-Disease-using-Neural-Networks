# %%
import tensorflow as tf
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5c4e2935-7cf8-4f76-b881-1faef3747bcd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c4e2935-7cf8-4f76-b881-1faef3747bcd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heart.csv to heart (1).csv

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
def clean(data):
  from sklearn.preprocessing import LabelEncoder
  le = LabelEncoder()

  columns = ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']

  for cols in columns:
    data[cols] = le.fit_transform(data[cols])

  return data

df = clean(df)
df
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1        140          289          0           1
# 1     49    0              2        160          180          0           1
# 2     37    1              1        130          283          0           2
# 3     48    0              0        138          214          0           1
# 4     54    1              2        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              3        110          264          0           1
# 914   68    1              0        144          193          1           1
# 915   57    1              0        130          131          0           1
# 916   57    0              1        130          236          0           0
# 917   38    1              2        138          175          0           1
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0      172               0      0.0         2             0
# 1      156               0      1.0         1             1
# 2       98               0      0.0         2             0
# 3      108               1      1.5         1             1
# 4      122               0      0.0         2             0
# ..     ...             ...      ...       ...           ...
# 913    132               0      1.2         1             1
# 914    141               0      3.4         1             1
# 915    115               1      1.2         1             1
# 916    174               0      0.0         1             1
# 917    173               0      0.0         2             0
#
# [918 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    int64
#  2   ChestPainType   918 non-null    int64
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    int64
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    int64
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    int64
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(11)
# memory usage: 86.2 KB

# %%
y = df['HeartDisease']
X = df.drop(['HeartDisease'], axis=1)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape
# Out:
# (734, 11)

# %%
from tensorflow import keras
from keras import layers

# %%
model = keras.Sequential()

# %%
model.add(layers.Dense(units=512, input_shape=[11], activation='relu'))
model.add(layers.Dense(units=512, activation='relu'))
model.add(layers.Dense(units=512, activation='relu'))
model.add(layers.Dense(units=1))

# %%
model.compile(loss='mae', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train,y_train, epochs=100)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 1s 12ms/step - loss: 0.3021 - accuracy: 0.7629
# Epoch 2/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.2047 - accuracy: 0.8351
# Epoch 3/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.1964 - accuracy: 0.8174
# Epoch 4/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2613 - accuracy: 0.7711
# Epoch 5/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.2082 - accuracy: 0.8161
# Epoch 6/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.2164 - accuracy: 0.8174
# Epoch 7/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1971 - accuracy: 0.8243
# Epoch 8/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2131 - accuracy: 0.8120
# Epoch 9/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2178 - accuracy: 0.8297
# Epoch 10/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1864 - accuracy: 0.8379
# Epoch 11/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1867 - accuracy: 0.8215
# Epoch 12/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1758 - accuracy: 0.8460
# Epoch 13/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1794 - accuracy: 0.8351
# Epoch 14/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2307 - accuracy: 0.7929
# Epoch 15/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2545 - accuracy: 0.7902
# Epoch 16/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2129 - accuracy: 0.8229
# Epoch 17/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2245 - accuracy: 0.8188
# Epoch 18/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1791 - accuracy: 0.8433
# Epoch 19/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2016 - accuracy: 0.8079
# Epoch 20/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1893 - accuracy: 0.8161
# Epoch 21/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1786 - accuracy: 0.8311
# Epoch 22/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1627 - accuracy: 0.8529
# Epoch 23/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1829 - accuracy: 0.8297
# Epoch 24/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2195 - accuracy: 0.7929
# Epoch 25/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2283 - accuracy: 0.7766
# Epoch 26/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2349 - accuracy: 0.7725
# Epoch 27/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2689 - accuracy: 0.7425
# Epoch 28/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2916 - accuracy: 0.7698
# Epoch 29/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1834 - accuracy: 0.8311
# Epoch 30/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2136 - accuracy: 0.7943
# Epoch 31/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2225 - accuracy: 0.7943
# Epoch 32/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2085 - accuracy: 0.8229
# Epoch 33/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2145 - accuracy: 0.8011
# Epoch 34/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1899 - accuracy: 0.8270
# Epoch 35/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1895 - accuracy: 0.8161
# Epoch 36/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2088 - accuracy: 0.7997
# Epoch 37/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2342 - accuracy: 0.7738
# Epoch 38/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1864 - accuracy: 0.8188
# Epoch 39/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1966 - accuracy: 0.8106
# Epoch 40/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2108 - accuracy: 0.7970
# Epoch 41/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2301 - accuracy: 0.7766
# Epoch 42/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1793 - accuracy: 0.8270
# Epoch 43/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1811 - accuracy: 0.8243
# Epoch 44/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2003 - accuracy: 0.8120
# Epoch 45/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1826 - accuracy: 0.8256
# Epoch 46/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1793 - accuracy: 0.8283
# Epoch 47/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1834 - accuracy: 0.8283
# Epoch 48/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2096 - accuracy: 0.7943
# Epoch 49/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2119 - accuracy: 0.7997
# Epoch 50/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1753 - accuracy: 0.8324
# Epoch 51/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1642 - accuracy: 0.8420
# Epoch 52/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1840 - accuracy: 0.8270
# Epoch 53/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1814 - accuracy: 0.8243
# Epoch 54/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1948 - accuracy: 0.8134
# Epoch 55/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2045 - accuracy: 0.8079
# Epoch 56/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1893 - accuracy: 0.8147
# Epoch 57/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2719 - accuracy: 0.7425
# Epoch 58/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2217 - accuracy: 0.7997
# Epoch 59/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2280 - accuracy: 0.7847
# Epoch 60/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2699 - accuracy: 0.7371
# Epoch 61/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3896 - accuracy: 0.6131
# Epoch 62/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2037 - accuracy: 0.8134
# Epoch 63/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1788 - accuracy: 0.8365
# Epoch 64/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1732 - accuracy: 0.8338
# Epoch 65/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1769 - accuracy: 0.8324
# Epoch 66/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1762 - accuracy: 0.8338
# Epoch 67/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1767 - accuracy: 0.8351
# Epoch 68/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1818 - accuracy: 0.8283
# Epoch 69/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1651 - accuracy: 0.8420
# Epoch 70/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2294 - accuracy: 0.7752
# Epoch 71/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2199 - accuracy: 0.7847
# Epoch 72/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1687 - accuracy: 0.8433
# Epoch 73/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1756 - accuracy: 0.8297
# Epoch 74/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1978 - accuracy: 0.8093
# Epoch 75/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2053 - accuracy: 0.7997
# Epoch 76/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2111 - accuracy: 0.7956
# Epoch 77/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2348 - accuracy: 0.7711
# Epoch 78/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2475 - accuracy: 0.7575
# Epoch 79/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2857 - accuracy: 0.7207
# Epoch 80/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2685 - accuracy: 0.7357
# Epoch 81/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2333 - accuracy: 0.7834
# Epoch 82/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1840 - accuracy: 0.8297
# Epoch 83/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1811 - accuracy: 0.8283
# Epoch 84/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2074 - accuracy: 0.7984
# Epoch 85/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1827 - accuracy: 0.8229
# Epoch 86/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2255 - accuracy: 0.7766
# Epoch 87/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2146 - accuracy: 0.7888
# Epoch 88/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1691 - accuracy: 0.8420
# Epoch 89/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1699 - accuracy: 0.8338
# Epoch 90/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1778 - accuracy: 0.8256
# Epoch 91/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1743 - accuracy: 0.8351
# Epoch 92/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2084 - accuracy: 0.8025
# Epoch 93/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2414 - accuracy: 0.7738
# Epoch 94/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2025 - accuracy: 0.8025
# Epoch 95/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2088 - accuracy: 0.7984
# Epoch 96/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2440 - accuracy: 0.7643
# Epoch 97/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1817 - accuracy: 0.8338
# Epoch 98/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2089 - accuracy: 0.8106
# Epoch 99/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1928 - accuracy: 0.8229
# Epoch 100/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1717 - accuracy: 0.8379
